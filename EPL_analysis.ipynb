# %% [markdown]
# <a href="https://colab.research.google.com/github/Janet-Priya/EPL-23-24-data-analysis/blob/main/EPL_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DECODING GOAL PATTERNS: A DATA DRIVEN ANALYSIS OF THE EPL 2023/24 SEASON**

# %%
#i am importing all the generic models for the data loading and the data exploration
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset and the testing of it

df=pd.read_csv('/content/matches.csv')

df.describe()
# Out:
#        Unnamed: 0          GF          GA          xG         xGA      Poss  \
# count  760.000000  760.000000  760.000000  760.000000  760.000000  760.0000
# mean    24.051316    1.639474    1.639474    1.550263    1.550263   50.0000
# std     14.518127    1.331297    1.331297    0.891314    0.891314   13.7495
# min      0.000000    0.000000    0.000000    0.000000    0.000000   18.0000
# 25%     11.750000    1.000000    1.000000    0.900000    0.900000   40.0000
# 50%     24.000000    1.000000    1.000000    1.400000    1.400000   50.0000
# 75%     36.000000    2.000000    2.000000    2.100000    2.100000   60.0000
# max     57.000000    8.000000    8.000000    7.000000    7.000000   82.0000
#
#          Attendance  Notes          Sh         SoT        Dist          FK  \
# count    760.000000    0.0  760.000000  760.000000  760.000000  760.000000
# mean   38613.313158    NaN   13.660526    4.668421   16.711842    0.372368
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0        Date   Time            Comp         Round  Day Venue  \
# 0           1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away
# 1           3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home
# 2           4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away
# 3           5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home
# 4           6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away
# 5           8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home
# 6          10  2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away
# 7          12  2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away
# 8          13  2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home
# 9          15  2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away
#
#   Result  GF  GA  ...  Match Report  Notes    Sh   SoT  Dist   FK PK PKatt  \
# 0      W   3   0  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    760 non-null    int64
#  1   Date          760 non-null    object
#  2   Time          760 non-null    object
#  3   Comp          760 non-null    object
#  4   Round         760 non-null    object
#  5   Day           760 non-null    object
#  6   Venue         760 non-null    object
#  7   Result        760 non-null    object
#  8   GF            760 non-null    int64
#  9   GA            760 non-null    int64
#  10  Opponent      760 non-null    object
#  11  xG            760 non-null    float64
#  12  xGA           760 non-null    float64
#  13  Poss          760 non-null    float64
#  14  Attendance    760 non-null    float64
#  15  Captain       760 non-null    object
#  16  Formation     760 non-null    object
#  17  Referee       760 non-null    object
# ...

# %%
df.isnull()
# Out:
#      Unnamed: 0   Date   Time   Comp  Round    Day  Venue  Result     GF  \
# 0         False  False  False  False  False  False  False   False  False
# 1         False  False  False  False  False  False  False   False  False
# 2         False  False  False  False  False  False  False   False  False
# 3         False  False  False  False  False  False  False   False  False
# 4         False  False  False  False  False  False  False   False  False
# ..          ...    ...    ...    ...    ...    ...    ...     ...    ...
# 755       False  False  False  False  False  False  False   False  False
# 756       False  False  False  False  False  False  False   False  False
# 757       False  False  False  False  False  False  False   False  False
# 758       False  False  False  False  False  False  False   False  False
# 759       False  False  False  False  False  False  False   False  False
#
#         GA  ...  Match Report  Notes     Sh    SoT   Dist     FK     PK  \
# ...

# %%
# convert to from date to datetime
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#    Unnamed: 0       Date   Time            Comp        Round  Day Venue  \
# 0           1 2023-08-11  20:00  Premier League  Matchweek 1  Fri  Away
# 1           3 2023-08-19  20:00  Premier League  Matchweek 2  Sat  Home
# 2           4 2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away
# 3           5 2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home
# 4           6 2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away
#
#   Result  GF  GA  ...  Match Report  Notes    Sh   SoT  Dist   FK PK PKatt  \
# 0      W   3   0  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# 1      W   1   0  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0     0
# 2      W   2   1  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0     1
# 3      W   5   1  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1     1
# 4      W   3   1  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0     0
#
#   Season            Team
# 0   2024  ManchesterCity
# 1   2024  ManchesterCity
# ...

# %%
#dropping columns that are not much needed
#dropping the unnamed, Comp, day, match report,notes,poss,attendence.

df.drop(columns=["Match Report", "Notes","Comp",'Attendance','Captain',"Formation","Referee","Unnamed: 0"], inplace=True)

# %%
df.head()
# Out:
#         Date   Time        Round  Day Venue Result  GF  GA       Opponent  \
# 0 2023-08-11  20:00  Matchweek 1  Fri  Away      W   3   0        Burnley
# 1 2023-08-19  20:00  Matchweek 2  Sat  Home      W   1   0  Newcastle Utd
# 2 2023-08-27  14:00  Matchweek 3  Sun  Away      W   2   1  Sheffield Utd
# 3 2023-09-02  15:00  Matchweek 4  Sat  Home      W   5   1         Fulham
# 4 2023-09-16  15:00  Matchweek 5  Sat  Away      W   3   1       West Ham
#
#     xG  xGA  Poss    Sh   SoT  Dist   FK  PK  PKatt  Season            Team
# 0  1.9  0.3  65.0  17.0   8.0  13.9  0.0   0      0    2024  ManchesterCity
# 1  1.0  0.3  59.0  14.0   4.0  17.9  0.0   0      0    2024  ManchesterCity
# 2  3.5  0.7  79.0  29.0   9.0  17.3  2.0   0      1    2024  ManchesterCity
# 3  2.2  1.4  68.0   6.0   4.0  14.8  0.0   1      1    2024  ManchesterCity
# 4  3.6  0.9  68.0  29.0  13.0  16.4  1.0   0      0    2024  ManchesterCity

# %%
df.drop(columns=["Season"],inplace=True)

# %%
df.isna()
#downloading the modified matches for the goal prediction part
df.to_csv("modified_matchess.csv", index=False)

# %%
#now for the data visualisation part of it
#the plot of goal distibution using a scatterplot

team_results = df.groupby("Team")["Result"].value_counts().unstack().fillna(1)
team_results.plot(kind="bar", stacked=True, figsize=(12, 6), colormap="viridis")

plt.xlabel("Team")
plt.ylabel("Number of Matches")
plt.title("Wins, Draws, and Losses per Team in EPL 2023/24")
plt.xticks(rotation=90)
plt.legend(["Losses", "Draws", "Wins"])
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# Inference:
# It seems that Manchester City has won more matches than any other team as well as the lowestt number of draws and losses
# On the other hand, Sheffield United has the less number of wins but the most number of draws
# The team with the highest number of losses is Brighton and Hove Albion

# %%
#Number of Home vs Away wins


# Count home and away wins
home_wins = df[(df['Venue'] == 'Home') & (df['Result'] == 'W')].shape[0]
away_wins = df[(df['Venue'] == 'Away') & (df['Result'] == 'W')].shape[0]

# Bar chart
plt.figure(figsize=(6, 4))
sns.barplot(x=['Home Wins', 'Away Wins'], y=[home_wins, away_wins], palette=['pink', 'cyan'])
plt.ylabel("Number of Wins")
plt.title("Home Wins vs Away Wins in EPL 2023/24")
plt.show()

#Inference
# It seems that many teams are winning in their home turf rather than in away games
# Out:
# <ipython-input-30-b37b5eac5319>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Home Wins', 'Away Wins'], y=[home_wins, away_wins], palette=['pink', 'cyan'])

# %%
#KDE graph for Expected Goals(xG) versus Actual Goals(GF)

plt.figure(figsize=(10,6))
sns.kdeplot(df['xG'], shade=True, label='Expected Goals (xG)', color='red')
sns.kdeplot(df['GF'], shade=True, label='Actual Goals (GF)', color='green')
plt.xlabel('Goals')
plt.ylabel('Density')
plt.title('Density Distribution of xG vs GA')
plt.grid(True)
plt.legend()
plt.show()

#Inference
#This KDE graph shows that the players are overperforming during each match ie goals are being scored more than the expected goals for most teams.
# Out:
# <ipython-input-31-6e7d3279b405>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['xG'], shade=True, label='Expected Goals (xG)', color='red')
# <ipython-input-31-6e7d3279b405>:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['GF'], shade=True, label='Actual Goals (GF)', color='green')

# %%
#KDE graph for Expected Goals conceded (xGA) versus Actual Goals Conceded(GA)

plt.figure(figsize=(10,6))
sns.kdeplot(df['xGA'], shade=True, label='Expected Goals conceded (xGA)', color='red')
sns.kdeplot(df['GA'], shade=True, label='Actual Goals conceded (GA)', color='BLUE')
plt.xlabel('Goals')
plt.ylabel('Density')
plt.title('Density Distribution of xG vs GA')
plt.grid(True)
plt.legend()
plt.show()

#Inference
#This KDE graph shows that there were actually lesser goals conceded than the expeceted goals to be conceded
# Out:
# <ipython-input-32-09aecf36ab56>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['xGA'], shade=True, label='Expected Goals conceded (xGA)', color='red')
# <ipython-input-32-09aecf36ab56>:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['GA'], shade=True, label='Actual Goals conceded (GA)', color='BLUE')

# %%
#Goals scored for their respective teams
plt.figure(figsize=(12,6))
for team in df['Team'].unique():
    team_df = df[df['Team'] == team]
    plt.plot(team_df['Date'], team_df['GF'].cumsum(), label=team)

plt.xlabel('Date')
plt.ylabel('Cumulative Goals')
plt.title('Goals Scored Over the Season')
plt.legend()
plt.grid(True)
plt.show()

#inference
#this line chart shows that Manchester City has scored the most goals as well as they were the winners of the EPL 2023/24 season
#On the other hand, Sheffield United has scared the least amount of goals

# %%
#Goals conceded  by the team using a Line chart
plt.figure(figsize=(12,6))
for team in df['Team'].unique():
    team_df = df[df['Team'] == team]
    plt.plot(team_df['Date'], team_df['GA'].cumsum(), label=team)

plt.xlabel('Date')
plt.ylabel('Cumulative Goals')
plt.title('Goals conceded Over the Season')
plt.legend()
plt.grid(True)
plt.show()

#inference
#this line chart shows us the team with the most goals conceded is Sheffield United
#However the less number of goals conceded is Arsenal

# %%
# Calculate successful and missed penalty kicks
penalty_data = {
    'Penalties scored': df['PK'].sum(),
    'Missed penalties': (df['PKatt'] - df['PK']).sum()
}

# Plot the pie chart
plt.figure(figsize=(8,8))
plt.pie(penalty_data.values(), labels=penalty_data.keys(), autopct='%1.1f%%', colors=['green', 'red'])
plt.title('Penalty Kick Success vs. Missed Attempts')
plt.show()

#Inference
#this below pie chart shows us that nearly 90% of the penaltiies are scored
#this also implies that many penalty kicks are a mak=jor way to score goals

# %%
#shots distance distribution by respective team

plt.figure(figsize=(12, 6))
sns.boxplot(x='Team', y='Dist', data=df)
plt.xticks(rotation=90)
plt.xlabel('Team')
plt.ylabel('Average Shot Distance (Dist)')
plt.title('Shot Distance Distribution by Team')
plt.show()

#Inference
#Teams like Manchester City and Arsenal take closer-range shots, indicating a more intricate attacking style, while
#Sheffield United and Burnley attempt longer-range shots, reflecting a more direct approach.
#Consistent shot distances in teams like Liverpool suggest structured play, whereas larger spreads in teams like Wolverhampton indicate varied attacking strategies.
